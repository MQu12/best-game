# %%
# %load_ext autoreload
# %autoreload 2

# %%
import monte_carlo
import pandas as pd

# %%
orderings = [f"Game {i}" for i in range(40)]
devs,maxs = monte_carlo.run_n_sims(orderings, False, False, 100, 1000)
pd.Series(devs).plot.hist()
pd.Series(devs).mean()
# Out:
# 4.6046000000000005

# %%
pd.Series(maxs).plot.hist()
pd.Series(maxs).mean()
# Out:
# 12.509

# %%
orderings = [f"Game {i}" for i in range(40)]
devs,maxs = monte_carlo.run_n_sims(orderings, True, False, 100, 1000)
pd.Series(devs).plot.hist()
pd.Series(devs).mean()
# Out:
# 3.9444

# %%
pd.Series(maxs).plot.hist()
pd.Series(maxs).mean()
# Out:
# 10.624

# %%
orderings = [f"Game {i}" for i in range(40)]
devs,maxs = monte_carlo.run_n_sims(orderings, True, True, 100, 1000)
pd.Series(devs).plot.hist()
pd.Series(devs).mean()
# Out:
# 3.2096999999999998

# %%
pd.Series(maxs).plot.hist()
pd.Series(maxs).mean()
# Out:
# 10.452
